# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamadimanna/DATA-STRUCTURE-VISUALSER/blob/main/Wavelet%2BGRU(LSTM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#WAVELET + GRU (coif5)
import numpy as np
import pandas as pd
import pywt
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load dataset (adjust file path if necessary)
df = pd.read_excel('LOAD-CONSUMPTION.xlsx')

# Extract and sort original data by date
df['DATE'] = pd.to_datetime(df['DATE'], format='%m-%d-%Y')
df = df.sort_values('DATE').reset_index(drop=True)
data = df['Value'].values

# Wavelet Transform for denoising
wavelet = 'coif5'
coeffs = pywt.wavedec(data, wavelet, level=5)  # Increased level for finer decomposition
threshold = np.median(np.abs(coeffs[-1])) / 0.6745  # Thresholding noise

# Apply soft thresholding on detail coefficients
coeffs[1:] = [pywt.threshold(c, value=threshold, mode='soft') for c in coeffs[1:]]
denoised_data = pywt.waverec(coeffs, wavelet)

# Plot original vs denoised signal
plt.figure(figsize=(12, 6))
plt.plot(signal, label='Original Signal', alpha=0.7)
plt.plot(denoised_signal, label='Denoised Signal', alpha=0.7)
plt.title('Original vs Denoised Signal')
plt.legend()
plt.show()

# Scale data for GRU model
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(denoised_data.reshape(-1, 1))

# Create sequences for training
seq_length = 60  # Increased sequence length to capture seasonal patterns
X, y = [], []
for i in range(len(scaled_data) - seq_length):
    X.append(scaled_data[i:i + seq_length])
    y.append(scaled_data[i + seq_length])

X, y = np.array(X), np.array(y)

# Split data into training and test sets
train_size = int(0.85 * len(X))  # Increased training data split
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build the GRU model
model = Sequential()
model.add(GRU(units=100, return_sequences=True, input_shape=(X_train.shape[1], 1)))  # Increased units
model.add(Dropout(0.1))  # Reduced dropout for more data retention
model.add(GRU(units=100, return_sequences=True))
model.add(Dropout(0.1))
model.add(GRU(units=50, return_sequences=False))
model.add(Dropout(0.1))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Train the GRU model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# Predict on test data
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test)

# Plot predictions vs actual values
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual', color='blue')
plt.plot(y_pred_inv, label='Predicted', color='red', linestyle='--')
plt.legend()
plt.title('Actual vs Predicted Values (Test Set)')
plt.show()

# Forecast future values (e.g., 1 year)
n_future = 28  # Days to forecast
last_sequence = scaled_data[-seq_length:]
current_seq = last_sequence.reshape(1, seq_length, 1)

predicted_future = []
for _ in range(n_future):
    future_pred = model.predict(current_seq)[0, 0]
    predicted_future.append(future_pred)
    future_pred = np.array(future_pred).reshape(1, 1, 1)
    current_seq = np.append(current_seq[:, 1:, :], future_pred, axis=1)

# Inverse transform predictions to original scale
predicted_future_inv = scaler.inverse_transform(np.array(predicted_future).reshape(-1, 1))

# Plot original data and future forecast
time_index = np.arange(len(data) + n_future)

plt.figure(figsize=(14, 7))
plt.plot(time_index[:len(data)], data, label='Original Data', color='blue')
plt.plot(time_index[len(data):], predicted_future_inv, label='1 Year Forecast', color='red', linestyle='--')
plt.title('Original Data and 1 Year Future Forecast')
plt.xlabel('Time')
plt.ylabel('kWh Consumption')
plt.legend()
plt.grid(True)
plt.show()

# Plot original, denoised, and forecasted data
plt.figure(figsize=(14, 7))
plt.plot(time_index[:len(data)], data, label='Original Data', color='blue', alpha=0.6)
plt.plot(time_index[:len(denoised_data)], denoised_data, label='Denoised Data', color='green', alpha=0.8)
plt.plot(time_index[len(data):], predicted_future_inv, label='1 Year Forecast', color='red', linestyle='--')

plt.title('Original, Denoised, and 1 Year Future Forecast')
plt.xlabel('Time')
plt.ylabel('kWh Consumption')
plt.legend()
plt.grid(True)
plt.show()

# Error analysis
mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
r2 = r2_score(y_test_inv, y_pred_inv)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/pywt/_multilevel.py:43: UserWarning: Level value of 5 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru_56 (GRU)                         │ (None, 60, 100)             │          30,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
#WAVELET + GRU (sym4)
import numpy as np
import pandas as pd
import pywt
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load dataset (adjust file path if necessary)
df = pd.read_excel('LOAD-CONSUMPTION.xlsx')

# Extract and sort original data by date
df['DATE'] = pd.to_datetime(df['DATE'], format='%m-%d-%Y')
df = df.sort_values('DATE').reset_index(drop=True)
data = df['Value'].values

# Wavelet Transform for denoising
wavelet = 'sym4'
coeffs = pywt.wavedec(data, wavelet, level=5)  # Increased level for finer decomposition
threshold = np.median(np.abs(coeffs[-1])) / 0.6745  # Thresholding noise

# Apply soft thresholding on detail coefficients
coeffs[1:] = [pywt.threshold(c, value=threshold, mode='soft') for c in coeffs[1:]]
denoised_data = pywt.waverec(coeffs, wavelet)

# Plot original vs denoised signal
plt.figure(figsize=(12, 6))
plt.plot(signal, label='Original Signal', alpha=0.7)
plt.plot(denoised_signal, label='Denoised Signal', alpha=0.7)
plt.title('Original vs Denoised Signal')
plt.legend()
plt.show()

# Scale data for GRU model
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(denoised_data.reshape(-1, 1))

# Create sequences for training
seq_length = 60  # Increased sequence length to capture seasonal patterns
X, y = [], []
for i in range(len(scaled_data) - seq_length):
    X.append(scaled_data[i:i + seq_length])
    y.append(scaled_data[i + seq_length])

X, y = np.array(X), np.array(y)

# Split data into training and test sets
train_size = int(0.85 * len(X))  # Increased training data split
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build the GRU model
model = Sequential()
model.add(GRU(units=100, return_sequences=True, input_shape=(X_train.shape[1], 1)))  # Increased units
model.add(Dropout(0.1))  # Reduced dropout for more data retention
model.add(GRU(units=100, return_sequences=True))
model.add(Dropout(0.1))
model.add(GRU(units=50, return_sequences=False))
model.add(Dropout(0.1))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Train the GRU model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# Predict on test data
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test)

# Plot predictions vs actual values
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual', color='blue')
plt.plot(y_pred_inv, label='Predicted', color='red', linestyle='--')
plt.legend()
plt.title('Actual vs Predicted Values (Test Set)')
plt.show()

# Forecast future values (e.g., 1 year)
n_future = 28  # Days to forecast
last_sequence = scaled_data[-seq_length:]
current_seq = last_sequence.reshape(1, seq_length, 1)

predicted_future = []
for _ in range(n_future):
    future_pred = model.predict(current_seq)[0, 0]
    predicted_future.append(future_pred)
    future_pred = np.array(future_pred).reshape(1, 1, 1)
    current_seq = np.append(current_seq[:, 1:, :], future_pred, axis=1)

# Inverse transform predictions to original scale
predicted_future_inv = scaler.inverse_transform(np.array(predicted_future).reshape(-1, 1))

# Plot original data and future forecast
time_index = np.arange(len(data) + n_future)

plt.figure(figsize=(14, 7))
plt.plot(time_index[:len(data)], data, label='Original Data', color='blue')
plt.plot(time_index[len(data):], predicted_future_inv, label='1 Year Forecast', color='red', linestyle='--')
plt.title('Original Data and 1 Year Future Forecast')
plt.xlabel('Time')
plt.ylabel('kWh Consumption')
plt.legend()
plt.grid(True)
plt.show()

# Plot original, denoised, and forecasted data
plt.figure(figsize=(14, 7))
plt.plot(time_index[:len(data)], data, label='Original Data', color='blue', alpha=0.6)
plt.plot(time_index[:len(denoised_data)], denoised_data, label='Denoised Data', color='green', alpha=0.8)
plt.plot(time_index[len(data):], predicted_future_inv, label='1 Year Forecast', color='red', linestyle='--')

plt.title('Original, Denoised, and 1 Year Future Forecast')
plt.xlabel('Time')
plt.ylabel('kWh Consumption')
plt.legend()
plt.grid(True)
plt.show()

# Error analysis
mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
r2 = r2_score(y_test_inv, y_pred_inv)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru_62 (GRU)                         │ (None, 60, 100)             │          30,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_86 (Dropout)                 │ (None, 60, 100)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...
